# %% [markdown]
# <a href="https://colab.research.google.com/github/Rini43/Case-Study-on-Supervised-Learning/blob/main/Bank_Account__Weather_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bank Account Manager

# %%
# Bank Account Manager

account_holder = "Amal"
account_number = "13080502002220"
def mask_account_number (account_number):
    account_number  = account_number .replace(" ", "")
    return "*" * (len(account_number ) - 3) + account_number [-3:]
print(account_holder)
print(mask_account_number("13080502002220"))
account_type = "Savings"
ifsc_code = "SBIN0000712"
balance = 75000.0
# Out:
# Amal
# ***********220

# %%
# Function to deposit money
# Let assume this branch has 1 cr money
Total_amount = 10000000
balance = 75000.0
user_deposit= float(input("Enter the deposit amount (in Rupees): "))
if user_deposit > 0:
  Total_amount += user_deposit
  balance += user_deposit
  print("\n--- Deposit Successful ---")
  print(f"Amount Deposited: Rs. {user_deposit:}")
  print(f"Your Updated Account Balance: Rs. {balance:}")
  print(f"Total Branch Deposits: Rs. {Total_amount:}")
else:
  print("Please enter a deposit amount greater than zero.")
# Out:
# Enter the deposit amount (in Rupees): 2143244424
#
# --- Deposit Successful ---
# Amount Deposited: Rs. 2143244424.0
# Your Updated Account Balance: Rs. 2143319424.0
# Total Branch Deposits: Rs. 2153244424.0

# %%
# Function to withdraw money

user_withdrawal = float(input("Enter the withdrawal amount (in Rupees): "))

if user_withdrawal > 0:
        if user_withdrawal <= balance:
            balance -= user_withdrawal
            Total_amount -= user_withdrawal
            print("\n--- Withdrawal Successful ---")
            print(f"Amount Withdrawn: Rs. {user_withdrawal:}")
            print(f"Updated Balance: Rs. {balance:}")
            print(f"Total Branch Deposits: Rs. {Total_amount:}")
        else:
            print("Insufficient balance.")
else:
        print("Please enter a valid amount.")
# Out:
# Enter the withdrawal amount (in Rupees): 1441242
#
# --- Withdrawal Successful ---
# Amount Withdrawn: Rs. 1441242.0
# Updated Balance: Rs. 2141878182.0
# Total Branch Deposits: Rs. 2151803182.0

# %%
total_amount = 10000000
balance = 75000.0

print("\n===== BANK ACCOUNT MANAGER =====")
print("1. Deposit")
print("2. Withdraw")
print("3. Balance Enquiry")

choice = input("Enter your choice (1, 2, or 3): ")

if choice == "1":
    user_deposit = float(input("Enter the deposit amount (in Rupees): "))

    if user_deposit > 0:
        total_amount += user_deposit
        balance += user_deposit

        print("\n--- Deposit Successful ---")
        print(f"Amount Deposited: Rs. {user_deposit:}")
        print(f"Your Updated Account Balance: Rs. {balance:}")
        print(f"Total Branch Deposits: Rs. {total_amount:}")
    else:
        print("Please enter a valid amount.")

elif choice == "2":
    user_withdrawal = float(input("Enter the withdrawal amount (in Rupees): "))

    if user_withdrawal > 0:
        if user_withdrawal <= balance:
            balance -= user_withdrawal
            total_amount -= user_withdrawal

            print("\n--- Withdrawal Successful ---")
            print(f"Amount Withdrawn: Rs. {user_withdrawal:}")
            print(f"Updated Balance: Rs. {balance:}")
            print(f"Total Branch Deposits: Rs. {total_amount:}")
        else:
            print("Insufficient balance.")
    else:
        print("Please enter a valid amount.")

elif choice == "3":
    print("\n--- Balance Enquiry ---")
    print(f"Current Account Balance: Rs. {balance:}")

else:
    print("Invalid choice.")
# Out:
# ===== BANK ACCOUNT MANAGER =====
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# Enter your choice (1, 2, or 3): 3
#
# --- Balance Enquiry ---
# Current Account Balance: Rs. 75000.0

# %% [markdown]
# ##  Weather Data Analyzer

# %%
# Weather Data Analyzer
region = "Kerala"
temperatures = [32, 34, 31, 33, 35]
humidities = [65, 70, 68, 72, 66]
print("===== WEATHER DATA ANALYZER =====")
print("Region:", region)
print("Temperature Data:", temperatures)
print("Humidity Data:", humidities)
# Out:
# ===== WEATHER DATA ANALYZER =====
# Region: Kerala
# Temperature Data: [32, 34, 31, 33, 35]
# Humidity Data: [65, 70, 68, 72, 66]

# %%
average_temperatures = sum(temperatures) / len(temperatures)
average_humidity = sum(humidities) / len(humidities)
def weather_condition(avg_temp, avg_humidity):
    if avg_temp > 30 and avg_humidity < 70:
        return "Sunny"
    elif avg_humidity >= 70:
        return "Rainy"
    else:
        return "Cloudy"

condition = weather_condition(average_temperatures, average_humidity)

print(f"Average Temperature: {average_temperatures}°C")
print(f"Average Humidity: {average_humidity}%")
print("Weather Condition:", condition)
# Out:
# Average Temperature: 33.0°C
# Average Humidity: 68.2%
# Weather Condition: Sunny
